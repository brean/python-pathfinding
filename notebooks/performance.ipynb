# %% [markdown]
# Simple notebook showing one performance test result in plot.

# %%
import numpy
from pathfinding.core.diagonal_movement import DiagonalMovement
from pathfinding.core.grid import Grid
from pathfinding.finder.a_star import AStarFinder
import matplotlib.pyplot as plt

# %%
def _add_block(g: numpy.ndarray, x: int, y: int, padding: int):
    for i in range(x - padding, x + padding):
        for j in range(y - padding, y + padding):
            g[j][i] = 0

"""Test performance."""
# Get a 500 x 500 grid
grid = numpy.ones((500, 500), numpy.int32)

# Add a block at the center
_add_block(grid, 250, 250, 50)

finder_grid = Grid(matrix=grid)
start = finder_grid.node(0, 0)
end = finder_grid.node(400, 400)

finder = AStarFinder(diagonal_movement=DiagonalMovement.never)
path, runs = finder.find_path(start, end, finder_grid)

# print runs, path
print(runs)
print(path)

# update grid
for p in path:
    grid[p.y][p.x] = 0


plt.rcParams['figure.figsize'] = [10, 10] # increase size of image so we can see the path
plt.matshow(grid)
# Out:
# 150801
# [<GridNode(0:0 0x12c5e5e50)>, <GridNode(1:0 0x12d061700)>, <GridNode(2:0 0x12d061100)>, <GridNode(3:0 0x12d061ca0)>, <GridNode(4:0 0x12d061c70)>, <GridNode(5:0 0x12d061c40)>, <GridNode(6:0 0x12d061c10)>, <GridNode(7:0 0x12d065d60)>, <GridNode(8:0 0x12d065d30)>, <GridNode(9:0 0x12d065cd0)>, <GridNode(10:0 0x12d065ca0)>, <GridNode(11:0 0x12d065c70)>, <GridNode(12:0 0x12d065c40)>, <GridNode(13:0 0x12d065c10)>, <GridNode(14:0 0x12d065be0)>, <GridNode(15:0 0x12d065bb0)>, <GridNode(16:0 0x12d065b80)>, <GridNode(17:0 0x12d065b50)>, <GridNode(18:0 0x12d065b20)>, <GridNode(19:0 0x12d065af0)>, <GridNode(20:0 0x12d065640)>, <GridNode(21:0 0x12d065610)>, <GridNode(22:0 0x12d0655e0)>, <GridNode(23:0 0x12d0655b0)>, <GridNode(24:0 0x12d065580)>, <GridNode(25:0 0x12d065550)>, <GridNode(26:0 0x12d065520)>, <GridNode(27:0 0x12d0654f0)>, <GridNode(28:0 0x12d0654c0)>, <GridNode(29:0 0x12d065490)>, <GridNode(30:0 0x12be7c2b0)>, <GridNode(31:0 0x12be7cac0)>, <GridNode(32:0 0x12be7c5b0)>, <GridNode(33:0 0x12be7cfa0)>, <GridNode(34:0 0x12ca9b790)>, <GridNode(35:0 0x12ca9b520)>, <GridNode(36:0 0x12ca9beb0)>, <GridNode(37:0 0x12ca9bf10)>, <GridNode(38:0 0x12ca9bee0)>, <GridNode(39:0 0x12ca9b4f0)>, <GridNode(40:0 0x12ca9b7f0)>, <GridNode(41:0 0x12ca9b430)>, <GridNode(42:0 0x12ca9b400)>, <GridNode(43:0 0x12be54bb0)>, <GridNode(44:0 0x12be54ac0)>, <GridNode(45:0 0x12be54eb0)>, <GridNode(46:0 0x12be54d00)>, <GridNode(47:0 0x12be54af0)>, <GridNode(48:0 0x12be54b20)>, <GridNode(49:0 0x12be54a30)>, <GridNode(50:0 0x12be54040)>, <GridNode(51:0 0x12be54280)>, <GridNode(52:0 0x12be54c10)>, <GridNode(53:0 0x12be54be0)>, <GridNode(54:0 0x12cb8e040)>, <GridNode(55:0 0x12cb8e070)>, <GridNode(56:0 0x12cb8e0a0)>, <GridNode(57:0 0x12cb8e0d0)>, <GridNode(58:0 0x12cb8e100)>, <GridNode(59:0 0x12cb8e130)>, <GridNode(60:0 0x12cb8e160)>, <GridNode(61:0 0x12cb8e190)>, <GridNode(62:0 0x12cb8e1c0)>, <GridNode(63:0 0x12cb8e1f0)>, <GridNode(64:0 0x12cb8e220)>, <GridNode(65:0 0x12cb8e250)>, <GridNode(66:0 0x12cb8e280)>, <GridNode(67:0 0x12cb8e2b0)>, <GridNode(68:0 0x12cb8e2e0)>, <GridNode(69:0 0x12cb8e310)>, <GridNode(70:0 0x12cb8e340)>, <GridNode(71:0 0x12cb8e370)>, <GridNode(72:0 0x12cb8e3a0)>, <GridNode(73:0 0x12cb8e3d0)>, <GridNode(74:0 0x12cb8e400)>, <GridNode(75:0 0x12cb8e430)>, <GridNode(76:0 0x12cb8e460)>, <GridNode(77:0 0x12cb8e490)>, <GridNode(78:0 0x12cb8e4c0)>, <GridNode(79:0 0x12cb8e4f0)>, <GridNode(80:0 0x12cb8e520)>, <GridNode(81:0 0x12cb8e550)>, <GridNode(82:0 0x12cb8e580)>, <GridNode(83:0 0x12cb8e5b0)>, <GridNode(84:0 0x12cb8e5e0)>, <GridNode(85:0 0x12cb8e610)>, <GridNode(86:0 0x12cb8e640)>, <GridNode(87:0 0x12cb8e670)>, <GridNode(88:0 0x12cb8e6a0)>, <GridNode(89:0 0x12cb8e6d0)>, <GridNode(90:0 0x12cb8e700)>, <GridNode(91:0 0x12cb8e730)>, <GridNode(92:0 0x12cb8e760)>, <GridNode(93:0 0x12cb8e790)>, <GridNode(94:0 0x12cb8e7c0)>, <GridNode(95:0 0x12cb8e7f0)>, <GridNode(96:0 0x12cb8e820)>, <GridNode(97:0 0x12cb8e850)>, <GridNode(98:0 0x12cb8e880)>, <GridNode(99:0 0x12cb8e8b0)>, <GridNode(100:0 0x12cb8e8e0)>, <GridNode(101:0 0x12cb8e910)>, <GridNode(102:0 0x12cb8e940)>, <GridNode(103:0 0x12cb8e970)>, <GridNode(104:0 0x12cb8e9a0)>, <GridNode(105:0 0x12cb8e9d0)>, <GridNode(106:0 0x12cb8ea00)>, <GridNode(107:0 0x12cb8ea30)>, <GridNode(108:0 0x12cb8ea60)>, <GridNode(109:0 0x12cb8ea90)>, <GridNode(110:0 0x12cb8eac0)>, <GridNode(111:0 0x12cb8eaf0)>, <GridNode(112:0 0x12cb8eb20)>, <GridNode(113:0 0x12cb8eb50)>, <GridNode(114:0 0x12cb8eb80)>, <GridNode(115:0 0x12cb8ebb0)>, <GridNode(116:0 0x12cb8ebe0)>, <GridNode(117:0 0x12cb8ec10)>, <GridNode(118:0 0x12cb8ec40)>, <GridNode(119:0 0x12cb8ec70)>, <GridNode(120:0 0x12cb8eca0)>, <GridNode(121:0 0x12cb8ecd0)>, <GridNode(122:0 0x12cb8ed00)>, <GridNode(123:0 0x12cb8ed30)>, <GridNode(124:0 0x12cb8ed60)>, <GridNode(125:0 0x12cb8ed90)>, <GridNode(126:0 0x12cb8edc0)>, <GridNode(127:0 0x12cb8edf0)>, <GridNode(128:0 0x12cb8ee20)>, <GridNode(129:0 0x12cb8ee50)>, <GridNode(130:0 0x12cb8ee80)>, <GridNode(131:0 0x12cb8eeb0)>, <GridNode(132:0 0 ...
